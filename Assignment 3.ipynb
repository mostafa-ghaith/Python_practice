# %% [markdown]
# # Assignment 3

# %% [markdown]
# ### Write a function to count the number 4 in a given list.

# %%
def count4(lst):
    count=0
    for n in lst:
        if n==4:
            count+=1
    return count

#testing
count4([1,2,3,4,4,5,6,4,3])
# Out:
# 3

# %% [markdown]
# ### write a  function to check whether a number is divisible by another number.

# %%
def isdiv(num1,num2):
    if num1%num2==0:
        return True
    else:
        return False
    
#testing
print(isdiv(9,3))
print(isdiv(9,4))
# Out:
# True
# False

# %% [markdown]
# ### write a function to find the maximum and minimum numbers from a sequence of numbers.

# %%
def maxmin(lst):
    max=lst[0]
    min=lst[0]
    for n in lst:
        if n>max:
            max=n
        if n<min:
            min=n
    return(max,min)

#testing
maxmin([10,2,3,4,6,60])
# Out:
# (60, 2)

# %% [markdown]
# ### Write a Python function that takes two lists and returns True if they have at least one common member.

# %%
def common(l1,l2):
    out=False
    for i in l1:
        for j in l2:
            if i==j:
                out=True
    return(out)
            
#testing
common([1,3,5,7,8],[6,22,34,4,5])
# Out:
# True

# %% [markdown]
# ### Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number from the user

# %%
def fact_rec(num):
    if num==1:
        return 1
    else:
        return num*fact_rec(num-1)
    
#testing
fact_rec(4)
# Out:
# 24

# %% [markdown]
# ### Write a Python function to check whether a number is in a given range.
#
# ### The range is from 3 to 11

# %%
def rangecheck(num):
    if num>=3 and num<=11:
        return True
    else:
        return False
    
#testing
print(rangecheck(100))
print(rangecheck(3))
# Out:
# False
# True

# %% [markdown]
# ### Write a  program to create the multiplication table (from 1 to 10) of a number.

# %%
def mulTable(num):
    for n in range(10):
        print(n+1,'x',num,'=',(n+1)*num)

        
#testing
mulTable(2)
# Out:
# 1 x 2 = 2
# 2 x 2 = 4
# 3 x 2 = 6
# 4 x 2 = 8
# 5 x 2 = 10
# 6 x 2 = 12
# 7 x 2 = 14
# 8 x 2 = 16
# 9 x 2 = 18
# 10 x 2 = 20

# %% [markdown]
# #### LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers *if* both numbers are even, but returns the greater if one or both numbers are odd
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(num1,num2):
    if num1%2==0 and num2%2==0:
        if num1>num2:
            return num2
        else:
            return num1
        
    else:
        if num1>num2:
            return num1
        else:
            return num2
        
#testing
print(lesser_of_two_evens(2,4))
print(lesser_of_two_evens(2,5))
# Out:
# 2
# 5

# %% [markdown]
# #### ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter
#     animal_crackers('Levelheaded Llama') --> True
#     animal_crackers('Crazy Kangaroo') --> False

# %%
def animal_crackers(st):
    strList=st.split()
    if strList[0][0]==strList[1][0]:
        return True
    else:
        return False
    
print(animal_crackers('Levelheaded Llama'))
print(animal_crackers('Crazy Kangaroo'))
# Out:
# True
# False

# %% [markdown]
# #### MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 *or* if one of the integers is 20. If not, return False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def makes_twenty(num1,num2):
    if num1==20 and num2!=20:  #assuming that if the 2 numbers are 20 it should return false
        return True
    if num2==20 and num1!=20:
        return True
    if num1+num2==20:
        return True
    else:
        return False

#testing
print(makes_twenty(11,9))
print(makes_twenty(20,4))
print(makes_twenty(2,4))
print(makes_twenty(20,20)) #the assumed case
# Out:
# True
# True
# False
# False

# %% [markdown]
# #### ALMOST THERE: Given an integer n, return True if n is within 10 of either 100 or 200
#
#     almost_there(90) --> True
#     almost_there(104) --> True
#     almost_there(150) --> False
#     almost_there(209) --> True
#
# NOTE: `abs(num)` returns the absolute value of a number

# %%
def almost_there(num):
    if num>=90 and num<=110 or num>=190 and num<=210:
        return True
    else: 
        return False
    
print(almost_there(90))
print(almost_there(104)) 
print(almost_there(150))
print(almost_there(209))
# Out:
# True
# True
# False
# True

# %% [markdown]
# #### BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 *and* there's an eleven, reduce the total sum by 10. Finally, if the sum  exceeds 21, return 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
def blackjack(num1,num2,num3):
    total=num1+num2+num3
    if total<=21:
        return total
    elif total>21 and num1==11 or num2==11 or num3==11:
        return total-10
    elif total>21:
        return ('BUST')
    
#testing
print(blackjack(5,6,7))
print(blackjack(9,9,9))
print(blackjack(9,9,11))
# Out:
# 18
# BUST
# 19
